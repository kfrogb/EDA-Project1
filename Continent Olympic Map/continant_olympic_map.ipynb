# %%
# Dependencies
import pandas as pd
import requests
import time
import json
import operator as op
import numpy as np
import hvplot.pandas
from config import api_key
from scipy.stats import linregress
from matplotlib import pyplot as plt

# %%
# Import cities file as DataFrame
data_df = pd.read_csv("athlete_events.csv")
data_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# checking columns of dataframe
data_df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
# Unique cities that held Olympic games
cities_held_games = data_df['City'].unique()
cities_held_games
# Out:
# array(['Barcelona', 'London', 'Antwerpen', 'Paris', 'Calgary',
#        'Albertville', 'Lillehammer', 'Los Angeles', 'Salt Lake City',
#        'Helsinki', 'Lake Placid', 'Sydney', 'Atlanta', 'Stockholm',
#        'Sochi', 'Nagano', 'Torino', 'Beijing', 'Rio de Janeiro', 'Athina',
#        'Squaw Valley', 'Innsbruck', 'Sarajevo', 'Mexico City', 'Munich',
#        'Seoul', 'Berlin', 'Oslo', "Cortina d'Ampezzo", 'Melbourne',
#        'Roma', 'Amsterdam', 'Montreal', 'Moskva', 'Tokyo', 'Vancouver',
#        'Grenoble', 'Sapporo', 'Chamonix', 'St. Louis', 'Sankt Moritz',
#        'Garmisch-Partenkirchen'], dtype=object)

# %%
summer_host_data = pd.read_csv("summer_host_cities.csv")
summer_host_data.head()
# Out:
#   summer_host_city      Continent
# 0           Greece         Europe
# 1           France         Europe
# 2    United States  North America
# 3   United Kingdom         Europe
# 4           Sweden         Europe

# %%
summer_host_data_clean = summer_host_data.dropna()
summer_host_data_clean
# Out:
#                                      summer_host_city      Continent
# 0                                              Greece         Europe
# 1                                              France         Europe
# 2                                       United States  North America
# 3                                      United Kingdom         Europe
# 4                                              Sweden         Europe
# 5                                             Belgium         Europe
# 6                                         Netherlands         Europe
# 7                                             Germany         Europe
# 8                                             Finland         Europe
# 9                                           Australia        Oceania
# 10                                              Italy         Europe
# 11                                              Japan           Asia
# 12                                             Mexico   Noth America
# ...

# %%
winter_host_data = pd.read_csv("winter_host_cities.csv")
winter_host_data.head()
# Out:
#   winter_host_country      continent
# 0              France         Europe
# 1         Switzerland         Europe
# 2       United States  North America
# 3             Germany         Europe
# 4              Norway         Europe

# %%
winter_host_data_clean = winter_host_data.dropna()
winter_host_data_clean
# Out:
#    winter_host_country      continent
# 0               France         Europe
# 1          Switzerland         Europe
# 2        United States  North America
# 3              Germany         Europe
# 4               Norway         Europe
# 5                Italy         Europe
# 6              Austria         Europe
# 7                Japan           Asia
# 8           Yugoslavia         Europe
# 9               Canada  North America
# 10              Russia         Europe
# 11         South Korea           Asia
# 12               China           Asia

# %%
countries_vs_continents = pd.read_csv("all_host_cities.csv")
countries_vs_continents.head()
# Out:
#   all_host_countries      continent
# 0          Australia        Oceania
# 1            Austria         Europe
# 2            Belgium         Europe
# 3             Brazil  South America
# 4             Canada  North America

# %%
cities_coordinates = pd.read_csv("olym.csv")
cities_coordinates.head()
# Out:
#         City         Country  NOC Summer Winter  Year   Latitude  Longitude
# 0     Athens          Greece  GRE      I    NaN  1896  37.983333  23.733334
# 1      Paris          France  FRA     II    NaN  1900  48.853410   2.348800
# 2  St. Louis   United States  USA    III    NaN  1904  38.627273 -90.197891
# 3     London  United Kingdom  GBR     IV    NaN  1908  51.508415  -0.125533
# 4  Stockholm          Sweden  SWE      V    NaN  1912  59.332577  18.064903

# %%
# %%capture --no-display

# Configure the map plot
plot_1 = cities_coordinates.hvplot.points(
    'Longitude',
    'Latitude',
    geo=True, 
    tiles = 'OSM', 
    frame_width = 700, 
    frame_height = 500, 
    color='City',
    alpha= 0.5,
    title='Host Cities from 1896 - 2016',
    scale= 0.8)

# Display the map
plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (City)
